# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

PATH_TO_ROOT = "D:/Personal Coding/bizinnovate-2023/dhs_train"
IMAGE_NAME = "IA-2015-7-00010088.npz"
data = np.load(os.path.join(PATH_TO_ROOT, IMAGE_NAME))

image = data['x']

plt.figure()
f, axarr = plt.subplots(2,4, figsize=(15,8)) 
axarr[0][0].imshow(image[0])
axarr[0][1].imshow(image[1])
axarr[0][2].imshow(image[2])
axarr[0][3].imshow(image[3])
axarr[1][0].imshow(image[4])
axarr[1][1].imshow(image[5])
axarr[1][2].imshow(image[6])
axarr[1][3].imshow(image[7])

rgb = image[0:3]
print(rgb.shape)
plt.imshow(np.transpose(rgb, (1,2,0)))
# Out:
# (3, 255, 255)
